# %% [markdown]
# Try Except Introduction

# %% [markdown]
# Try Except Basics

# %%
x = 10
y = 20

# %%
print(x)
# Out:
# 10

# %%
try:
    print(z)
except Exception as e:
    print(e)
except:
    print('There was an error')
else:
    print('ELSE WAS TRIGGERED')
finally:
    print("FINALLY")
# Out:
# name 'z' is not defined
# FINALLY

# %% [markdown]
# Try Except with Files

# %%
path = r'C:\Users\khairil.akub\Desktop\Mohd Khairil\Personal\Personal Development\Python\Try_and_Error\MainFile.txt'

# %%
with open(path, 'r') as open_file:
    print(open_file.read())
# Out:
# This is from my Main File!
#
# Yay! :D

# %%
import os

# %%
try:
    with open(r'C:\Users\khairil.akub\Desktop\Mohd Khairil\Personal\Personal Development\Python\Try_and_Error\NewData2.txt', 'r') as open_file:
        append_to_main = open_file.read()
        #print("Variable Created")
except Exception as e:
    print(e)
else:
    with open(path, 'a') as append_file:
        append_file.write(append_to_main)
finally:
    with open(path, 'r') as open_file:
        print(open_file.read())
# Out:
# [Errno 2] No such file or directory: 'C:\\Users\\khairil.akub\\Desktop\\Mohd Khairil\\Personal\\Personal Development\\Python\\Try_and_Error\\NewData2.txt'
# This is from my Main File!
#
# Yay! :DThis is data we wanted to append.

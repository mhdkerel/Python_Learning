# %% [markdown]
# Creating an Index

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\khairil.akub\Desktop\Mohd Khairil\Personal\Personal Development\Python\Pandas\Indexing\Creating an Index\WorldContinents.csv',
                encoding = 'ISO-8859-1')

pd.set_option('display.max.rows', 1359)
pd.set_option('display.max.columns', 15)

# %%
df
# Out:
#     continent                 sub_region  \
# 0        Asia              Southern Asia
# 1      Europe            Northern Europe
# 2      Europe            Southern Europe
# 3      Africa            Northern Africa
# 4     Oceania                  Polynesia
# 5      Europe            Southern Europe
# 6      Africa              Middle Africa
# 7    Americas                  Caribbean
# 8    Americas                  Caribbean
# 9    Americas              South America
# 10       Asia               Western Asia
# 11   Americas                  Caribbean
# 12    Oceania  Australia and New Zealand
# 13     Europe             Western Europe
# 14       Asia               Western Asia
# 15   Americas                  Caribbean
# 16       Asia               Western Asia
# 17       Asia              Southern Asia
# 18   Americas                  Caribbean
# 19     Europe             Eastern Europe
# 20     Europe             Western Europe
# 21   Americas            Central America
# ...

# %%
df_world = pd.read_csv(r'C:\Users\khairil.akub\Desktop\Mohd Khairil\Personal\Personal Development\Python\Pandas\Indexing\Creating an Index\WorldContinents.csv',
                encoding = 'ISO-8859-1', index_col = 'country')

df_world
# Out:
#                                                    continent  \
# country
# Afghanistan                                             Asia
# Åland Islands                                         Europe
# Albania                                               Europe
# Algeria                                               Africa
# American Samoa                                       Oceania
# Andorra                                               Europe
# Angola                                                Africa
# Anguilla                                            Americas
# Antigua and Barbuda                                 Americas
# Argentina                                           Americas
# Armenia                                                 Asia
# Aruba                                               Americas
# Australia                                            Oceania
# Austria                                               Europe
# ...

# %%
df_Continent = pd.read_csv(r'C:\Users\khairil.akub\Desktop\Mohd Khairil\Personal\Personal Development\Python\Pandas\Indexing\Creating an Index\WorldContinents.csv',
                encoding = 'ISO-8859-1', index_col = 'continent')

df_Continent
# Out:
#                           sub_region  \
# continent
# Asia                   Southern Asia
# Europe               Northern Europe
# Europe               Southern Europe
# Africa               Northern Africa
# Oceania                    Polynesia
# Europe               Southern Europe
# Africa                 Middle Africa
# Americas                   Caribbean
# Americas                   Caribbean
# Americas               South America
# Asia                    Western Asia
# Americas                   Caribbean
# Oceania    Australia and New Zealand
# Europe                Western Europe
# Asia                    Western Asia
# Americas                   Caribbean
# Asia                    Western Asia
# Asia                   Southern Asia
# Americas                   Caribbean
# Europe                Eastern Europe
# Europe                Western Europe
# Americas             Central America
# Africa                Western Africa
# Americas            Northern America
# ...

# %%
df_world.loc['Albania']
# Out:
# continent              Europe
# sub_region    Southern Europe
# code_3                    ALB
# Unnamed: 4         3,300,000
# Name: Albania, dtype: object

# %%
df_Continent.loc['Asia']
# Out:
#                    sub_region                                  country code_3  \
# continent
# Asia            Southern Asia                              Afghanistan    AFG
# Asia             Western Asia                                  Armenia    ARM
# Asia             Western Asia                               Azerbaijan    AZE
# Asia             Western Asia                                  Bahrain    BHR
# Asia            Southern Asia                               Bangladesh    BGD
# Asia            Southern Asia                                   Bhutan    BTN
# Asia       South-Eastern Asia                        Brunei Darussalam    BRN
# Asia       South-Eastern Asia                                 Cambodia    KHM
# Asia             Eastern Asia                                    China    CHN
# Asia             Western Asia                                   Cyprus    CYP
# Asia             Western Asia                                  Georgia    GEO
# ...

# %%
df.set_index('country', inplace = True)

# %%
df
# Out:
#                                                    continent  \
# country
# Afghanistan                                             Asia
# Åland Islands                                         Europe
# Albania                                               Europe
# Algeria                                               Africa
# American Samoa                                       Oceania
# Andorra                                               Europe
# Angola                                                Africa
# Anguilla                                            Americas
# Antigua and Barbuda                                 Americas
# Argentina                                           Americas
# Armenia                                                 Asia
# Aruba                                               Americas
# Australia                                            Oceania
# Austria                                               Europe
# ...

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                                                country continent  \
# 0                                          Afghanistan      Asia
# 1                                        Åland Islands    Europe
# 2                                              Albania    Europe
# 3                                              Algeria    Africa
# 4                                       American Samoa   Oceania
# 5                                              Andorra    Europe
# 6                                               Angola    Africa
# 7                                             Anguilla  Americas
# 8                                  Antigua and Barbuda  Americas
# 9                                            Argentina  Americas
# 10                                             Armenia      Asia
# 11                                               Aruba  Americas
# 12                                           Australia   Oceania
# ...

# %% [markdown]
# Multi-Level Indexing

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\khairil.akub\Desktop\Mohd Khairil\Personal\Personal Development\Python\Pandas\Indexing\Creating an Index\WorldContinents.csv',
                encoding = 'ISO-8859-1')

pd.set_option('display.max.rows', 1359)
pd.set_option('display.max.columns', 15)

# %%
df
# Out:
#     continent                 sub_region  \
# 0        Asia              Southern Asia
# 1      Europe            Northern Europe
# 2      Europe            Southern Europe
# 3      Africa            Northern Africa
# 4     Oceania                  Polynesia
# 5      Europe            Southern Europe
# 6      Africa              Middle Africa
# 7    Americas                  Caribbean
# 8    Americas                  Caribbean
# 9    Americas              South America
# 10       Asia               Western Asia
# 11   Americas                  Caribbean
# 12    Oceania  Australia and New Zealand
# 13     Europe             Western Europe
# 14       Asia               Western Asia
# 15   Americas                  Caribbean
# 16       Asia               Western Asia
# 17       Asia              Southern Asia
# 18   Americas                  Caribbean
# 19     Europe             Eastern Europe
# 20     Europe             Western Europe
# 21   Americas            Central America
# ...

# %%
df_continent = df.set_index(['continent', 'sub_region']).sort_values(by = ['continent', 'sub_region'], ascending = [False, True])

# %%
df_continent
# Out:
#                                                                                country  \
# continent sub_region
# Oceania   Australia and New Zealand                                          Australia
#           Australia and New Zealand                                        New Zealand
#           Australia and New Zealand                                     Norfolk Island
#           Melanesia                                                               Fiji
#           Melanesia                                                      New Caledonia
#           Melanesia                                                   Papua New Guinea
#           Melanesia                                                    Solomon Islands
#           Melanesia                                                            Vanuatu
#           Micronesia                                                              Guam
# ...

# %%
df_continent.loc['Oceania']
# Out:
#                                                     country code_3  \
# sub_region
# Australia and New Zealand                         Australia    AUS
# Australia and New Zealand                       New Zealand    NZL
# Australia and New Zealand                    Norfolk Island    NFK
# Melanesia                                              Fiji    FJI
# Melanesia                                     New Caledonia    NCL
# Melanesia                                  Papua New Guinea    PNG
# Melanesia                                   Solomon Islands    SLB
# Melanesia                                           Vanuatu    VUT
# Micronesia                                             Guam    GUM
# Micronesia                                         Kiribati    KIR
# Micronesia                                 Marshall Islands    MHL
# Micronesia                 Micronesia (Federated States of)    FSM
# Micronesia                                            Nauru    NRU
# ...

# %% [markdown]
# Filtering Indexes with loc and iloc

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\khairil.akub\Desktop\Mohd Khairil\Personal\Personal Development\Python\Pandas\Indexing\Creating an Index\WorldContinents.csv',
                encoding = 'ISO-8859-1')

pd.set_option('display.max.rows', 1359)
pd.set_option('display.max.columns', 15)

# %%
df
# Out:
#     continent                 sub_region  \
# 0        Asia              Southern Asia
# 1      Europe            Northern Europe
# 2      Europe            Southern Europe
# 3      Africa            Northern Africa
# 4     Oceania                  Polynesia
# 5      Europe            Southern Europe
# 6      Africa              Middle Africa
# 7    Americas                  Caribbean
# 8    Americas                  Caribbean
# 9    Americas              South America
# 10       Asia               Western Asia
# 11   Americas                  Caribbean
# 12    Oceania  Australia and New Zealand
# 13     Europe             Western Europe
# 14       Asia               Western Asia
# 15   Americas                  Caribbean
# 16       Asia               Western Asia
# 17       Asia              Southern Asia
# 18   Americas                  Caribbean
# 19     Europe             Eastern Europe
# 20     Europe             Western Europe
# 21   Americas            Central America
# ...

# %%
df.loc[0]
# Out:
# continent              Asia
# sub_region    Southern Asia
# country         Afghanistan
# code_3                  AFG
# Unnamed: 4       6,900,000
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# continent              Asia
# sub_region    Southern Asia
# country         Afghanistan
# code_3                  AFG
# Unnamed: 4       6,900,000
# Name: 0, dtype: object

# %%
df.set_index(['country'], inplace = True)

# %%
df
# Out:
#                                                    continent  \
# country
# Afghanistan                                             Asia
# Åland Islands                                         Europe
# Albania                                               Europe
# Algeria                                               Africa
# American Samoa                                       Oceania
# Andorra                                               Europe
# Angola                                                Africa
# Anguilla                                            Americas
# Antigua and Barbuda                                 Americas
# Argentina                                           Americas
# Armenia                                                 Asia
# Aruba                                               Americas
# Australia                                            Oceania
# Austria                                               Europe
# ...

# %%
df.loc['Afghanistan']
# Out:
# continent              Asia
# sub_region    Southern Asia
# code_3                  AFG
# Unnamed: 4       6,900,000
# Name: Afghanistan, dtype: object

# %%
df.iloc[0]
# Out:
# continent              Asia
# sub_region    Southern Asia
# code_3                  AFG
# Unnamed: 4       6,900,000
# Name: Afghanistan, dtype: object

# %%
df.reset_index(inplace = True)

# %%
df.set_index('continent', inplace = True)

# %%
df
# Out:
#            index                                            country  \
# continent
# Asia           0                                        Afghanistan
# Europe         1                                      Åland Islands
# Europe         2                                            Albania
# Africa         3                                            Algeria
# Oceania        4                                     American Samoa
# Europe         5                                            Andorra
# Africa         6                                             Angola
# Americas       7                                           Anguilla
# Americas       8                                Antigua and Barbuda
# Americas       9                                          Argentina
# Asia          10                                            Armenia
# Americas      11                                              Aruba
# Oceania       12                                          Australia
# ...

# %%
df.loc['Asia']
# Out:
#            index                                  country          sub_region  \
# continent
# Asia           0                              Afghanistan       Southern Asia
# Asia          10                                  Armenia        Western Asia
# Asia          14                               Azerbaijan        Western Asia
# Asia          16                                  Bahrain        Western Asia
# Asia          17                               Bangladesh       Southern Asia
# Asia          24                                   Bhutan       Southern Asia
# Asia          30                        Brunei Darussalam  South-Eastern Asia
# Asia          35                                 Cambodia  South-Eastern Asia
# Asia          42                                    China        Eastern Asia
# Asia          53                                   Cyprus        Western Asia
# Asia          75                                  Georgia        Western Asia
# ...

# %%
df.iloc[0]
# Out:
# index                     0
# country         Afghanistan
# sub_region    Southern Asia
# code_3                  AFG
# Unnamed: 4       6,900,000
# Name: Asia, dtype: object

# %%
df.reset_index(inplace = True)

# %%
df_continent = df.set_index(['continent', 'sub_region'])

# %%
df_continent
# Out:
#                                      index  \
# continent sub_region
# Asia      Southern Asia                  0
# Europe    Northern Europe                1
#           Southern Europe                2
# Africa    Northern Africa                3
# Oceania   Polynesia                      4
# Europe    Southern Europe                5
# Africa    Middle Africa                  6
# Americas  Caribbean                      7
#           Caribbean                      8
#           South America                  9
# Asia      Western Asia                  10
# Americas  Caribbean                     11
# Oceania   Australia and New Zealand     12
# Europe    Western Europe                13
# Asia      Western Asia                  14
# Americas  Caribbean                     15
# Asia      Western Asia                  16
#           Southern Asia                 17
# Americas  Caribbean                     18
# Europe    Eastern Europe                19
# ...

# %%
df_continent.loc['Asia', 'Southern Asia']
# Out:
# C:\Users\khairil.akub\AppData\Local\Temp\ipykernel_24488\249281347.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df_continent.loc['Asia', 'Southern Asia']
#                          index                     country code_3  \
# continent sub_region
# Asia      Southern Asia      0                 Afghanistan    AFG
#           Southern Asia     17                  Bangladesh    BGD
#           Southern Asia     24                      Bhutan    BTN
#           Southern Asia     95                       India    IND
#           Southern Asia     97  Iran (Islamic Republic of)    IRN
#           Southern Asia    128                    Maldives    MDV
#           Southern Asia    148                       Nepal    NPL
#           Southern Asia    160                    Pakistan    PAK
#           Southern Asia    201                   Sri Lanka    LKA
#
#                               Unnamed: 4
# continent sub_region
# ...

# %%
df_continent.iloc[0]
# Out:
# index                   0
# country       Afghanistan
# code_3                AFG
# Unnamed: 4     6,900,000
# Name: (Asia, Southern Asia), dtype: object

# %%
df_continent.iloc[0,1]
# Out:
# 'Afghanistan'

# %% [markdown]
# Reordering and Sorting Indexes

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\khairil.akub\Desktop\Mohd Khairil\Personal\Personal Development\Python\Pandas\Indexing\Creating an Index\WorldContinents.csv',
                encoding = 'ISO-8859-1')

pd.set_option('display.max.rows', 1359)
pd.set_option('display.max.columns', 15)

# %%
df
# Out:
#     continent                 sub_region  \
# 0        Asia              Southern Asia
# 1      Europe            Northern Europe
# 2      Europe            Southern Europe
# 3      Africa            Northern Africa
# 4     Oceania                  Polynesia
# 5      Europe            Southern Europe
# 6      Africa              Middle Africa
# 7    Americas                  Caribbean
# 8    Americas                  Caribbean
# 9    Americas              South America
# 10       Asia               Western Asia
# 11   Americas                  Caribbean
# 12    Oceania  Australia and New Zealand
# 13     Europe             Western Europe
# 14       Asia               Western Asia
# 15   Americas                  Caribbean
# 16       Asia               Western Asia
# 17       Asia              Southern Asia
# 18   Americas                  Caribbean
# 19     Europe             Eastern Europe
# 20     Europe             Western Europe
# 21   Americas            Central America
# ...

# %%
df.set_index(['continent', 'sub_region']).sort_index(ascending = (False, True))
# Out:
#                                                                                country  \
# continent sub_region
# Oceania   Australia and New Zealand                                          Australia
#           Australia and New Zealand                                        New Zealand
#           Australia and New Zealand                                     Norfolk Island
#           Melanesia                                                               Fiji
#           Melanesia                                                      New Caledonia
#           Melanesia                                                   Papua New Guinea
#           Melanesia                                                    Solomon Islands
#           Melanesia                                                            Vanuatu
#           Micronesia                                                              Guam
# ...

# %%
df.set_index(['continent', 'sub_region'], inplace = True)

# %%
df
# Out:
#                                                                                country  \
# continent sub_region
# Asia      Southern Asia                                                    Afghanistan
# Europe    Northern Europe                                                Åland Islands
#           Southern Europe                                                      Albania
# Africa    Northern Africa                                                      Algeria
# Oceania   Polynesia                                                     American Samoa
# Europe    Southern Europe                                                      Andorra
# Africa    Middle Africa                                                         Angola
# Americas  Caribbean                                                           Anguilla
#           Caribbean                                                Antigua and Barbuda
# ...

# %%
df.swaplevel('continent','sub_region')
# Out:
#                                                                                country  \
# sub_region                continent
# Southern Asia             Asia                                             Afghanistan
# Northern Europe           Europe                                         Åland Islands
# Southern Europe           Europe                                               Albania
# Northern Africa           Africa                                               Algeria
# Polynesia                 Oceania                                       American Samoa
# Southern Europe           Europe                                               Andorra
# Middle Africa             Africa                                                Angola
# Caribbean                 Americas                                            Anguilla
#                           Americas                                 Antigua and Barbuda
# ...

# %% [markdown]
# Reshaping and Pivoting Indexes

# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\khairil.akub\Desktop\Mohd Khairil\Personal\Personal Development\Python\Pandas\Indexing\Reshaping and Pivoting Indexes\tech_price.xlsx'
                  , header = [0,1], index_col = [0,1])

pd.set_option('display.max.rows', 1350)
pd.set_option('display.max.columns', 15)

# %%
df
# Out:
#                    USD                 EUR
# company           open high low close open high low close
# 2023-01-01 Apple    89   26  68    69   37   56  11    25
#            Google   66   71  26    83   96   68  91    11
#            Amazon   12   43  97    75   25   25  90    43
# 2023-01-02 Apple    54   49  77    49   68   44  85    68
#            Google   84   92  55    90   51   50  59    68
#            Amazon   41   86  13    19   41   36  50    26
# 2023-01-03 Apple    67   47  46    70   41   62  72    49
#            Google   60   70  54    71   78   47  12    57
#            Amazon   71   15  47    53   86   44  68    33
# 2023-01-04 Apple    56   50  54    83   59   36  45    19
#            Google   36   77  27    94   62   13  66    90
#            Amazon   64   97  64    56   48   57  45    50
# 2023-01-05 Apple    34   45  60    84   24   49  63    54
#            Google   69   92  14    63   21   85  80    87
# ...

# %%
df2 = df.stack()
df2
# Out:
# C:\Users\khairil.akub\AppData\Local\Temp\ipykernel_24488\2801194021.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df2 = df.stack()
#                            USD  EUR
#                   company
# 2023-01-01 Apple  close     69   25
#                   high      26   56
#                   low       68   11
#                   open      89   37
#            Google close     83   11
#                   high      71   68
#                   low       26   91
#                   open      66   96
#            Amazon close     75   43
#                   high      43   25
#                   low       97   90
#                   open      12   25
# 2023-01-02 Apple  close     49   68
#                   high      49   44
#                   low       77   85
# ...

# %%
df2.unstack()
# Out:
#                     USD                 EUR
# company           close high low open close high low open
# 2023-01-01 Amazon    75   43  97   12    43   25  90   25
#            Apple     69   26  68   89    25   56  11   37
#            Google    83   71  26   66    11   68  91   96
# 2023-01-02 Amazon    19   86  13   41    26   36  50   41
#            Apple     49   49  77   54    68   44  85   68
#            Google    90   92  55   84    68   50  59   51
# 2023-01-03 Amazon    53   15  47   71    33   44  68   86
#            Apple     70   47  46   67    49   62  72   41
#            Google    71   70  54   60    57   47  12   78
# 2023-01-04 Amazon    56   97  64   64    50   57  45   48
#            Apple     83   50  54   56    19   36  45   59
#            Google    94   77  27   36    90   13  66   62
# 2023-01-05 Amazon    43   75  27   63    30   63  95   91
#            Apple     84   45  60   34    54   49  63   24
# ...

# %%
df_world = pd.read_csv(r'C:\Users\khairil.akub\Desktop\Mohd Khairil\Personal\Personal Development\Python\Pandas\Indexing\Creating an Index\WorldContinents.csv',
                encoding = 'ISO-8859-1')

pd.set_option('display.max.rows', 1359)
pd.set_option('display.max.columns', 15)

# %%
df_world
# Out:
#     continent                 sub_region  \
# 0        Asia              Southern Asia
# 1      Europe            Northern Europe
# 2      Europe            Southern Europe
# 3      Africa            Northern Africa
# 4     Oceania                  Polynesia
# 5      Europe            Southern Europe
# 6      Africa              Middle Africa
# 7    Americas                  Caribbean
# 8    Americas                  Caribbean
# 9    Americas              South America
# 10       Asia               Western Asia
# 11   Americas                  Caribbean
# 12    Oceania  Australia and New Zealand
# 13     Europe             Western Europe
# 14       Asia               Western Asia
# 15   Americas                  Caribbean
# 16       Asia               Western Asia
# 17       Asia              Southern Asia
# 18   Americas                  Caribbean
# 19     Europe             Eastern Europe
# 20     Europe             Western Europe
# 21   Americas            Central America
# ...

# %%
df_world.pivot(index = 'country', columns = 'continent' , values = 'sub_region')
# Out:
# continent                                                    Africa  \
# country
# Afghanistan                                                     NaN
# Albania                                                         NaN
# Algeria                                             Northern Africa
# American Samoa                                                  NaN
# Andorra                                                         NaN
# Angola                                                Middle Africa
# Anguilla                                                        NaN
# Antigua and Barbuda                                             NaN
# Argentina                                                       NaN
# Armenia                                                         NaN
# Aruba                                                           NaN
# Australia                                                       NaN
# Austria                                                         NaN
# ...

# %%
df_world.pivot(index = 'country', columns = 'continent' , values = 'Unnamed: 4')
# Out:
# continent                                                  Africa  \
# country
# Afghanistan                                                   NaN
# Albania                                                       NaN
# Algeria                                                9,500,000
# American Samoa                                                NaN
# Andorra                                                       NaN
# Angola                                                54,000,000
# Anguilla                                                      NaN
# Antigua and Barbuda                                           NaN
# Argentina                                                     NaN
# Armenia                                                       NaN
# Aruba                                                         NaN
# Australia                                                     NaN
# Austria                                                       NaN
# ...

# %%
df_world.pivot(index = 'country', columns = ['continent', 'sub_region'] , values = 'Unnamed: 4')
# Out:
# continent                                                      Asia  \
# sub_region                                            Southern Asia
# country
# Afghanistan                                              6,900,000
# Albania                                                         NaN
# Algeria                                                         NaN
# American Samoa                                                  NaN
# Andorra                                                         NaN
# Angola                                                          NaN
# Anguilla                                                        NaN
# Antigua and Barbuda                                             NaN
# Argentina                                                       NaN
# Armenia                                                         NaN
# Aruba                                                           NaN
# Australia                                                       NaN
# ...

# %%
# Logical operators

# %%
love_mems = 'I love membership operators!'

'hate' in love_mems
# Out:
# False

# %%
my_list = [1,2,3,4,5]
num_wanted = 9

num_wanted in my_list
# Out:
# False

# %%
my_list = [1,2,3,4,5]
num_wanted = 9

num_wanted not in my_list
# Out:
# True

# %%
my_dictionary = {1:'Hey!',2:'Hello!'}
#1 in my_dictionary

'Hey!' in my_dictionary.values()
# Out:
# True

# %%
# Assignment Operators

# %%
num = 5

num = num + 5

print(num)
# Out:
# 10

# %%
num = 5

num += 5 #in place operator

print(num)
# Out:
# 10

# %%
num = 5

num -= 5

print(num)
# Out:
# 0

# %%
num = 5

num *= 5

print(num)
# Out:
# 25

# %%
num = 5

num /= 5

print(num)
# Out:
# 1.0

# %%
num = 5

num %= 5

print(num)
# Out:
# 0

# %%
num = 5

num **= 5

print(num)
# Out:
# 3125

# %%
# Identity and Bitwise Operators

# %%
x = [1,8,'Love']
y = [1,8,'Love']
z = x

# %%
x is z
# Out:
# True

# %%
x is y
# Out:
# False

# %%
x == y
# Out:
# True

# %%
a = 20
b = 5

# %%
bin(b)
# Out:
# '0b101'

# %%
bin(a)
# Out:
# '0b10100'

# %%
a & b
# Out:
# 4

# %%
bin(a & b)
# Out:
# '0b100'

# %%
bin(0b100)
# Out:
# '0b100'

# %% [markdown]
# Function + Passing Arguments

# %%
def first_function():
    print('We dit it!')

# %%
first_function()
# Out:
# We dit it!

# %%
def second_function(name):
    print(name, 'dit it!')

# %%
second_function('Alex')
# Out:
# Alex dit it!

# %%
def number_squared_func(number,power):
    print(number**power)

# %%
number_squared_func(3,2)
# Out:
# 9

# %% [markdown]
# Adding Docstring

# %%
def test_func(name):
    """This function allows you to print your name. That's it"""
    print(name)

# %%
test_func('Alex')
# Out:
# Alex

# %% [markdown]
# Default and Arbitrary Arguments

# %%
def number_squared_func(number, power):
    print(number**power)

# %%
number_squared_func(2,3)
# Out:
# 8

# %%
def number_squared_func2(number, power = 3):
    print(number**power)

number_squared_func2(2,5)
# Out:
# 32

# %%
args_tuple = (5,6,1,2,3,4)


def arg_func(*number):
    print(number[0]*number[1])

arg_func(*args_tuple)
# Out:
# 30

# %%
tuple_1 = ('John', 'Mickey', 'Sally')


def number_args(*word):
    print("Hello", word[1], " - Nice to meet you!")

# %%
number_args(*tuple_1)
# Out:
# Hello Mickey  - Nice to meet you!

# %% [markdown]
# Keyword and Arbitrary Keyword Arguments

# %%
def number_squared_func(number,power):
    print(number**power)

# %%
number_squared_func(2,3)
# Out:
# 8

# %%
number_squared_func(3,power = 2)
# Out:
# 9

# %%
## **Kwargs

def number_kwargs(**kwargs):
    print(kwargs['Greeting'], kwargs['Name'])

# %%
number_kwargs(Greeting = 'Howdy!', Name = 'Alex')
# Out:
# Howdy! Alex

# %%
def number_kwargs2(**Names):
    for key, value in Names.items():
        print(key + ': ' + value)

# %%
number_kwargs2(Name = 'Alex', Name2 = 'Sally', Name3 = 'Josh')
# Out:
# Name: Alex
# Name2: Sally
# Name3: Josh

# %%
my_dict = {'1': 'Alex', 'Johnny': 'Hey', '3': 'Watermelon'}

# %%
number_kwargs2(**my_dict)
# Out:
# 1: Alex
# Johnny: Hey
# 3: Watermelon

# %%
def wild_function(one, *two, **three):
    print(one)

    print(two[0],two[2])

    print(three.values())

# %%
my_dict2 = {'One' : 'Johnny', 'Two' : 'Ebenezer', 'Three' : 'Kanye'}

wild_function(23, *['Welp', 23, 'Howdy!'], **my_dict2)
# Out:
# 23
# Welp Howdy!
# dict_values(['Johnny', 'Ebenezer', 'Kanye'])

# %% [markdown]
# Lambda Functions

# %%
lambda x: x * 2
# Out:
# <function __main__.<lambda>(x)>

# %%
(lambda x: x * 2)(5)
# Out:
# 10

# %%
def real_func(x):
    print(x*2)

real_func(5)
# Out:
# 10

# %% [markdown]
# Print vs Return in Functions

# %%
def return_example():
    return 100

# %%
return_example()
# Out:
# 100

# %%
type(return_example())
# Out:
# int

# %%
def print_example():
    print(100)

# %%
print_example()
# Out:
# 100

# %%
type(print_example())
# Out:
# 100
# NoneType

# %%
return_example() + 100
# Out:
# 200

# %%
def happy_birthday(Name):
    return 'Happy Birthday ' + Name + '!'

# %%
happy_birthday('Johnny')
# Out:
# 'Happy Birthday Johnny!'
